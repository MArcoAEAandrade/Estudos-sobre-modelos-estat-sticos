# %% [markdown]
# <a href="https://colab.research.google.com/github/MArcoAEAandrade/Estudos-sobre-modelos-estat-sticos/blob/main/Lista_de_exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import matplotlib.pyplot as plt
import math
import scipy.stats as st
import numpy as np
from PIL import Image

uploaded = files.upload()
img = Image.open("image (26).png")

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-db816b6e-af15-4a8f-9b63-9a90aa498578" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db816b6e-af15-4a8f-9b63-9a90aa498578">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#dados
#A) P(X = 2 )

#BINOMINAL
p = 0.1 # probabilidade de ser defeituosos
n = 10 #componentes aleatórios
k = 2 #componentes defeituosos

resultado = round(st.binom.pmf(k, n, p),5)
print(resultado)
# Out:
# 0.19371

# %%
#B) P(X = 4 ) O PRIMEIRO COMPONENTE DEFEITUOSO NA 4° POSIÇÃO
#GEOMÉTRICA
p = 0.1 # probabilidade de ser defeituosos
k = 4 # tentativa desejada

resultado = round(st.geom.pmf(k, p),5)
print(resultado)
# Out:
# 0.0729

# %% [markdown]
# $$P(X = k) = \binom{k-1}{r-1} p^r (1-p)^{k-r}$$

# %%
#dados
#c) P(X = 3° componente defeituoso estar exatamente na 7° inspeção )

#BINOMINAL - negativa
P = 0.1 # probabilidade de ser defeituosos
k = 7 # némero de eventos
r = 3 #número de sucessos desejados (peças defeitusos)

math.comb(k-1,r-1) * P**r * (1-P)**(k-r)
round(math.comb(k-1,r-1) * P**r * (1-P)**(k-r), 5)
# Out:
# 0.00984

# %%
#dados
#d) P(X = 3° componente defeituoso estar exatamente na 7° inspeção )

#Hypergeometric
P = 0.1 # probabilidade de ser defeituosos
N = 50 #população
n = 5 #amostra
K = 8 #defeituosos
k = 2 #peças sejam defeituosas

resultado = st.hypergeom.pmf(k, N, n, K)
print(round(st.hypergeom.pmf(k, N, n, K), 5))
# Out:
# 0.15171

# %%
uploaded = files.upload()
img = Image.open("image (27).png")

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-00f2e7ad-6acb-4463-bd1c-3510bdcee946" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00f2e7ad-6acb-4463-bd1c-3510bdcee946">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#dados
#"X" = ligações
#a) P(X =  6)
lambd = 4
k = 6

resultado = round(st.poisson.pmf(k, lambd),5)
print(resultado)
# Out:
# 0.1042

# %%
#b) P(X <=  2)
lambd = 4
k = 2

resultado = round(st.poisson.cdf(k, lambd),5)
print(resultado)
# Out:
# 0.2381

# %%
#c) P(X => 10) = 1 - P(X < 10 )

lambd = 8
k = 9

resultado = 1 - st.poisson.cdf(k, lambd)
print(round(resultado, 5))
# Out:
# 0.28338

# %%
#d)E[X] = LAMBDA EM 5 MINUTOS E O DP
lambd = 4
T = 5
E = lambd * T
V = lambd * T
DP = math.sqrt(V)
print(DP)
# Out:
# 4.47213595499958

# %%
uploaded = files.upload()
img = Image.open("image (28).png")

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-6985c296-be80-4b11-80d2-23a666017e88" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6985c296-be80-4b11-80d2-23a666017e88">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#dados
u = 500 #horas
dp = 50 #horas
a = 450 #horas

#a) P(X < 450 )

p = round(st.norm.cdf(a, loc=u, scale=dp),5)
print(p)
# Out:
# 0.15866

# %%
#dados
u = 500 #horas
dp = 50 #horas
a = 480 #horas
b = 520 #horas

#b) P(480 <= X <= 520 )

p = round(st.norm.cdf(b, loc=u, scale=dp),5) - round(st.norm.cdf(a, loc=u, scale=dp),5)
print(p)
# Out:
# 0.31084

# %%
#dados
u = 500 #horas
dp = 50 #horas
a = 480 #horas
b = 520 #horas

#b) P(480 <= X <= 520 )

p = round(st.norm.cdf(b, loc=u, scale=dp),5) - round(st.norm.cdf(a, loc=u, scale=dp),5)
print(p)
# Out:
# 0.31084

# %%
#dados
#C
#P(T >= t ) = 0,90 = 1 - (T <= t ) = 0,10
u = 500 #horas
dp = 50 #horas
z = st.norm.ppf(0.1)
T = round(z * dp + u, 5)
print(T, 'HORAS')
# Out:
# 435.92242 HORAS

# %%
#dados
#D
#VALOR ESPERADO E VARIANCIA DA DITRIBUIÇÃO
u = 500 #horas
dp = 50 #horas
v = dp**2
print(v)
# Out:
# 2500

# %%
uploaded = files.upload()
img = Image.open("image (29).png")

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-deed9eb1-fbe1-41cc-b74d-92087b5f9b86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-deed9eb1-fbe1-41cc-b74d-92087b5f9b86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#dados
#a) P(X >= 20) horas = 1 - P(<= 20)
lambd = 0.05 #taxa de falha de um servidor
k = 20 #horas

resultado = 1 - st.expon.cdf(k, scale=1/lambd)
print(round(resultado, 5))
# Out:
# 0.36788

# %%
#b) P(X <= 5)
lambd = 0.05 #taxa de falha de um servidor
k = 5 #horas

resultado = st.expon.cdf(k, scale=1/lambd)
print(round(resultado, 5))
# Out:
# 0.2212

# %%
#b) E[X] e V(X)
lambd = 0.05 #taxa de falha de um servidor
u = 1/lambd
v = 1/lambd**2

print('esperança',u)
print('variancia', v)
# Out:
# esperança 20.0
# variancia 399.99999999999994
